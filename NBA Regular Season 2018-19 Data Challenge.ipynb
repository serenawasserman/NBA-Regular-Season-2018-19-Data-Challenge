# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import numpy as np
import pandas as pd

nba = pd.read_csv("nbastats2018-2019.csv")
nba
# Out:
#              Name  Height  Weight                   Team  Age    Salary  \
# 0    Alex Abrines      78     200  Oklahoma City Thunder   25   5455236
# 1      Quincy Acy      79     240           Phoenix Suns   28    213949
# 2    Jaylen Adams      74     190          Atlanta Hawks   22    236854
# 3    Steven Adams      84     265  Oklahoma City Thunder   25  24157304
# 4     Bam Adebayo      82     255             Miami Heat   21   2955840
# ..            ...     ...     ...                    ...  ...       ...
# 516    Trae Young      74     180          Atlanta Hawks   20   5356440
# 517   Cody Zeller      84     240      Charlotte Hornets   26  13528090
# 518  Tyler Zeller      84     253          Atlanta Hawks   29    106974
# 519    Ante Zizic      83     254    Cleveland Cavaliers   22   1952760
# 520   Ivica Zubac      85     240   Los Angeles Clippers   21   1544951
#
#      Points  Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS  \
# ...

# %%
nba["Age"].mean()
# Out:
# 25.900191938579656

# %% [markdown]
# # What player scored the most points?

# %%
#Question: Is there a better way to do this?

# %%
nba["Points"].max()

nba.loc[nba["Points"] == 36.1]
# Out:
#              Name  Height  Weight             Team  Age    Salary  Points  \
# 202  James Harden      77     220  Houston Rockets   29  30431854    36.1
#
#      Blocks  Steals  Assists  ...    MP   G   PER   OWS  DWS    WS   WS48  \
# 202     0.7     2.0      7.5  ...  36.8  78  30.6  11.4  3.8  15.2  0.254
#
#       USG   BPM  VORP
# 202  40.5  11.7   9.9
#
# [1 rows x 27 columns]

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
#QUESTION: WHAT IS A POST PLAYER?

# %%
nba["Blocks"].max()
nba.loc[nba["Blocks"] == 2.7]
# Out:
#              Name  Height  Weight            Team  Age   Salary  Points  \
# 476  Myles Turner      83     250  Indiana Pacers   22  3410284    13.3
#
#      Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS   WS48   USG  \
# 476     2.7     0.8      1.6  ...  28.6  74  18.0  1.9  4.4  6.3  0.144  20.0
#
#      BPM  VORP
# 476  3.3   2.8
#
# [1 rows x 27 columns]

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
nba["WP"] = nba["WS"]/nba["G"]
nba["WP"].max()
nba.loc[nba["WP"] == 0.2]
# Out:
#                      Name  Height  Weight             Team  Age    Salary  \
# 15  Giannis Antetokounmpo      83     242  Milwaukee Bucks   24  24157304
#
#     Points  Blocks  Steals  Assists  ...   G   PER  OWS  DWS    WS   WS48  \
# 15    27.7     1.5     1.3      5.9  ...  72  30.9  8.9  5.5  14.4  0.292
#
#      USG   BPM  VORP   WP
# 15  32.3  10.8   7.6  0.2
#
# [1 rows x 28 columns]

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
nba.columns
nba["FG3%"].max()
nba[["Name","FG3%"]].loc[nba["FG3%"] == 1.0]
# Out:
#               Name  FG3%
# 147   Trevon Duval   1.0
# 312  Scott Machado   1.0
# 352  Eric Moreland   1.0
# 439  Jordan Sibert   1.0

# %% [markdown]
# # Who played the most minutes during the season

# %%
nba["MP"].max()
nba.loc[nba["MP"] == 36.9]
# Out:
#              Name  Height  Weight                   Team  Age    Salary  \
# 37   Bradley Beal      77     207     Washington Wizards   25  25434263
# 179   Paul George      81     220  Oklahoma City Thunder   28  30560700
#
#      Points  Blocks  Steals  Assists  ...   G   PER  OWS  DWS    WS   WS48  \
# 37     25.6     0.7     1.5      5.5  ...  82  20.8  5.9  1.7   7.6  0.120
# 179    28.0     0.4     2.2      4.1  ...  77  23.3  7.0  4.9  11.9  0.201
#
#       USG  BPM  VORP        WP
# 37   28.4  2.8   3.7  0.092683
# 179  29.5  5.5   5.3  0.154545
#
# [2 rows x 28 columns]

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
nba["PER"].max()
nba.loc[nba["PER"] == 80.4]
# Out:
#         Name  Height  Weight             Team  Age  Salary  Points  Blocks  \
# 405  Zhou Qi      85     210  Houston Rockets   23  506134     2.0     0.0
#
#      Steals  Assists  ...  G   PER  OWS  DWS   WS   WS48   USG  BPM  VORP   WP
# 405     0.0      0.0  ...  1  80.4  0.0  0.0  0.0  1.261  43.4  9.5   0.0  0.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # What team had the youngest roster?

# %%
#Chicago Bulls
team_age = nba[["Team", "Age"]].groupby("Team").mean()
team_age.sort_values("Age")
# Out:
#                               Age
# Team
# Chicago Bulls           24.312500
# Sacramento Kings        24.400000
# Orlando Magic           24.533333
# New York Knicks         24.625000
# Phoenix Suns            24.761905
# Portland Trail Blazers  24.857143
# Indiana Pacers          25.058824
# Denver Nuggets          25.266667
# Brooklyn Nets           25.555556
# Boston Celtics          25.600000
# Memphis Grizzlies       25.647059
# Oklahoma City Thunder   25.750000
# New Orleans Pelicans    25.777778
# Cleveland Cavaliers     26.000000
# Charlotte Hornets       26.000000
# Detroit Pistons         26.266667
# Philadelphia 76ers      26.352941
# Atlanta Hawks           26.476190
# Los Angeles Lakers      26.625000
# Minnesota Timberwolves  26.625000
# Washington Wizards      26.764706
# Milwaukee Bucks         26.928571
# Los Angeles Clippers    27.105263
# Utah Jazz               27.133333
# Toronto Raptors         27.166667
# Golden State Warriors   27.866667
# ...

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
#Question: Why is this incorrect?

# %%
nba.sort_values("Salary", ascending = False)
# Out:
#                     Name  Height  Weight                 Team  Age   Salary  \
# 255         John Jenkins      76     215   Washington Wizards   27    99290
# 188      Devonte' Graham      74     185    Charlotte Hornets   23   988464
# 402        Dwight Powell      83     240     Dallas Mavericks   27  9631250
# 129  Matthew Dellavedova      76     200  Cleveland Cavaliers   28  9607500
# 157           Dante Exum      78     190            Utah Jazz   23  9600000
# ..                   ...     ...     ...                  ...  ...      ...
# 96       Tyler Cavanaugh      81     238                  NaN   24        -
# 92           Alex Caruso      77     186                  NaN   24        -
# 292           Damion Lee      78     210                  NaN   26        -
# 293       Walt Lemon Jr.      75     180                  NaN   26        -
# 175        Billy Garrett      78     213                  NaN   24        -
#
# ...

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
nba.columns
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP', 'WP'],
#       dtype='object')

# %%
nba["FT%"].min()
bad_players = nba.loc[nba["FT%"] == 0.0]
bad_players[["Name", "FT%"]]
# Out:
#                    Name  FT%
# 154         Jacob Evans  0.0
# 221   Haywood Highsmith  0.0
# 268      Terrence Jones  0.0
# 325      Tahjere McCall  0.0
# 356  Donatas Motiejunas  0.0
# 360         Dzanan Musa  0.0
# 502       C.J. Williams  0.0
